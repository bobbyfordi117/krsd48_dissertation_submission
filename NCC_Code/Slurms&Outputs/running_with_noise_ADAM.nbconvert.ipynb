# %%
#ALTERED FROM:https://towardsdatascience.com/audio-deep-learning-made-simple-sound-classification-step-by-step-cebc936bbe5
#READ METADATA FILE FOR TRAINING DATA
import pandas as pd
from pathlib import Path

user = 'krsd48' #change for each user

# Read metadata file
metadata_file = r'/home2/{}/crash-bang-wallop/data/data/metadata_2/METADATA_2.csv'.format(user)
metadata_file_noise = r'/home2/{}/crash-bang-wallop/data/data/metadata_2/METADATA_2_NOISE.csv'.format(user) 
mf = pd.read_csv(metadata_file)
nf = pd.read_csv(metadata_file_noise)

# Construct file path by concatenating fold and file name
mf['relative_path'] = '/' + mf['AUDIO'].astype(str)
nf['relative_path'] = '/' + nf['AUDIO'].astype(str)

# Take relevant columns
mf = mf[['relative_path', 'Y']]
nf = nf[['relative_path', 'Y']]

# Concatenate two dataframes
df = pd.concat([mf, nf], ignore_index=True)
df.head(2296) #show that df contains both noise and clean data
# Out:
#                                  relative_path  Y
# 0                  /fold_2/Bright_Black_10.wav  1
# 1                 /fold_2/Bright_Black_100.wav  1
# 2                 /fold_2/Bright_Black_101.wav  1
# 3                 /fold_2/Bright_Black_102.wav  1
# 4                 /fold_2/Bright_Black_103.wav  1
# ...                                        ... ..
# 2291                       /fold_2/Tool_99.wav  2
# 2292   /fold_2_noise/Bright_Black_10_noise.wav  1
# 2293  /fold_2_noise/Bright_Black_100_noise.wav  1
# 2294  /fold_2_noise/Bright_Black_101_noise.wav  1
# 2295  /fold_2_noise/Bright_Black_102_noise.wav  1
#
# [2296 rows x 2 columns]

# %%
import math, random
import torch
import torchaudio
from torchaudio import transforms
from IPython.display import Audio
import numpy as np

class AudioUtil():
  # ----------------------------
  # Load an audio file. Return the signal as a tensor and the sample rate
  # ----------------------------
  @staticmethod
  def open(audio_file):
    sig, sr = torchaudio.load(audio_file)
    return (sig, sr)
#convert mono to stereo
   # ----------------------------
  # Convert the given audio to the desired number of channels
  # ----------------------------
  @staticmethod
  def rechannel(aud, new_channel):
    sig, sr = aud

    if (sig.shape[0] == new_channel):
      # Nothing to do
      return aud

    if (new_channel == 1):
      # Convert from stereo to mono by selecting only the first channel
      resig = sig[:1, :]
    else:
      # Convert from mono to stereo by duplicating the first channel
      resig = torch.cat([sig, sig])

    return ((resig, sr))
 # ----------------------------
  # Since Resample applies to a single channel, we resample one channel at a time
  # ----------------------------
  @staticmethod
  def resample(aud, newsr):
    sig, sr = aud

    if (sr == newsr):
      # Nothing to do
      return aud

    num_channels = sig.shape[0]
    # Resample first channel
    resig = torchaudio.transforms.Resample(sr, newsr)(sig[:1,:])
    if (num_channels > 1):
      # Resample the second channel and merge both channels
      retwo = torchaudio.transforms.Resample(sr, newsr)(sig[1:,:])
      resig = torch.cat([resig, retwo])

    return ((resig, newsr))
 # ----------------------------
  # Pad (or truncate) the signal to a fixed length 'max_ms' in milliseconds
  # ----------------------------
  @staticmethod
  def pad_trunc(aud, max_ms):
    sig, sr = aud
    num_rows, sig_len = sig.shape
    max_len = sr//1000 * max_ms

    if (sig_len > max_len):
      # Truncate the signal to the given length
      sig = sig[:,:max_len]

    elif (sig_len < max_len):
      # Length of padding to add at the beginning and end of the signal
      pad_begin_len = random.randint(0, max_len - sig_len)
      pad_end_len = max_len - sig_len - pad_begin_len

      # Pad with 0s
      pad_begin = torch.zeros((num_rows, pad_begin_len))
      pad_end = torch.zeros((num_rows, pad_end_len))

      sig = torch.cat((pad_begin, sig, pad_end), 1)
      
    return (sig, sr)
  
  @staticmethod
  def noise(aud):
    signal, sr = aud
    noise_scalar = random.randint(0,4)*0.1               #random noise level           
    RMS = torch.sqrt(torch.mean(torch.square(signal)))    #scientific way of adding noise - see Bobby's Zotero for reference
    noise = torch.tensor(np.random.normal(0, RMS, signal.shape))
    signal_noise = torch.add(signal,noise,alpha = noise_scalar)
    signal_noise = signal_noise.float()
    return (signal_noise,sr)

 # ----------------------------
  # Shifts the signal to the left or right by some percent. Values at the end
  # are 'wrapped around' to the start of the transformed signal.
  # ----------------------------
  @staticmethod
  def time_shift(aud, shift_limit):
    sig,sr = aud
    _, sig_len = sig.shape
    shift_amt = int(random.random() * shift_limit * sig_len)
    return (sig.roll(shift_amt), sr)
  # ----------------------------
  # Generate a Spectrogram
  # ----------------------------
  @staticmethod
  def spectro_gram(aud, n_mels=64, n_fft=1024, hop_len=None):
    sig,sr = aud
    top_db = 80

    # spec has shape [channel, n_mels, time], where channel is mono, stereo etc
    spec = transforms.MelSpectrogram(sr, n_fft=n_fft, hop_length=hop_len, n_mels=n_mels)(sig)
    #spec = transforms.Spectrogram(n_fft=n_fft, hop_length=hop_len)(sig)

    # Convert to decibels
    spec = transforms.AmplitudeToDB(top_db=top_db)(spec)
    return (spec)
  # ----------------------------
  # Augment the Spectrogram by masking out some sections of it in both the frequency
  # dimension (ie. horizontal bars) and the time dimension (vertical bars) to prevent
  # overfitting and to help the model generalise better. The masked sections are
  # replaced with the mean value.
  # ----------------------------
  @staticmethod
  def spectro_augment(spec, max_mask_pct=0.1, n_freq_masks=1, n_time_masks=1):
    _, n_mels, n_steps = spec.shape
    mask_value = spec.mean()
    aug_spec = spec

    freq_mask_param = max_mask_pct * n_mels
    for _ in range(n_freq_masks):
      aug_spec = transforms.FrequencyMasking(freq_mask_param)(aug_spec, mask_value)

    time_mask_param = max_mask_pct * n_steps
    for _ in range(n_time_masks):
      aug_spec = transforms.TimeMasking(time_mask_param)(aug_spec, mask_value)

    return aug_spec

# %%
from torch.utils.data import DataLoader, Dataset, random_split
import torchaudio

# ----------------------------
# Sound Dataset
# ----------------------------
class SoundDS(Dataset):
  def __init__(self, df, data_path):
    self.df = df
    self.data_path = str(data_path)
    self.duration = 4000
    self.sr = 44100
    self.channel = 2
    self.shift_pct = 0.4
            
  # ----------------------------
  # Number of items in dataset
  # ----------------------------
  def __len__(self):
    return len(self.df)    
    
  # ----------------------------
  # Get i'th item in dataset
  # ----------------------------
  def __getitem__(self, idx):
    # Absolute file path of the audio file - concatenate the audio directory with
    # the relative path
    audio_file = self.data_path + self.df.loc[idx, 'relative_path']
    # Get the Class ID
    class_id = self.df.loc[idx, 'Y']

    aud = AudioUtil.open(audio_file)
    # Some sounds have a higher sample rate, or fewer channels compared to the
    # majority. So make all sounds have the same number of channels and same 
    # sample rate. Unless the sample rate is the same, the pad_trunc will still
    # result in arrays of different lengths, even though the sound duration is
    # the same.
    reaud = AudioUtil.resample(aud, self.sr)
    rechan = AudioUtil.rechannel(reaud, self.channel)
    noise_sig=AudioUtil.noise(rechan)

    dur_aud = AudioUtil.pad_trunc(noise_sig, self.duration)
    shift_aud = AudioUtil.time_shift(dur_aud, self.shift_pct)
    sgram = AudioUtil.spectro_gram(shift_aud, n_mels=64, n_fft=1024, hop_len=None)
    #aug_sgram = AudioUtil.spectro_augment(sgram, max_mask_pct=0.1, n_freq_masks=2, n_time_masks=2)

    return sgram, class_id

# %%
from torch.utils.data import random_split
from pathlib import Path
import os
import torch.nn.functional as F
import torch.nn as nn
from torch.nn import init

def inference (model, val_dl):
    correct_prediction = 0
    total_prediction = 0
    wrong=[]

  # Disable gradient updates
    with torch.no_grad():
        for data in val_dl:
      # Get the input features and target labels, and put them on the GPU
            inputs, labels = data[0].to(device), data[1].to(device)

      # Normalize the inputs
            inputs_m, inputs_s = inputs.mean(), inputs.std()
            inputs = (inputs - inputs_m) / inputs_s

      # Get predictions
            outputs = model(inputs)

      # Get the predicted class with the highest score
            _, prediction = torch.max(outputs,1)
            cpu_prediction = prediction.cpu().numpy()
            cpu_labels = labels.cpu().numpy()
            for i in range(len(cpu_prediction)):
                if cpu_prediction[i]!=cpu_labels[i]:
                    wrong.append([cpu_prediction[i],cpu_labels[i]])
                    
      # Count of predictions that matched the target label
            correct_prediction += (prediction == labels).sum().item()
            total_prediction += prediction.shape[0]
    #print(wrong)
    acc = correct_prediction/total_prediction
    print(f'Accuracy: {acc:.2f}, Total items: {total_prediction}')
    return acc,wrong


data_path=r'/home2/{}/crash-bang-wallop/data/data'.format(user) #change user (krsd48) as needed
myds = SoundDS(df, data_path)


# Random split of 80:20 between training and validation
num_items = len(myds)
num_train = round(num_items * 0.8)
num_val = num_items - num_train
train_ds, val_ds = random_split(myds, [num_train, num_val])
# Create training and validation data loaders
train_dl =torch.utils.data.DataLoader(train_ds, batch_size=16, shuffle=True)
val_dl = torch.utils.data.DataLoader(val_ds, batch_size=16, shuffle=False)
print(num_train)
print(num_val)
# Out:
# 3667
# 917

# %%
# ----------------------------
# Audio Classification Model
# ----------------------------
class AudioClassifier (nn.Module):
    # ----------------------------
    # Build the model architecture
    # ----------------------------
    def __init__(self):
        super().__init__()
        conv_layers = []

        # First Convolution Block with Relu and Batch Norm. Use Kaiming Initialization
        self.conv1 = nn.Conv2d(2, 8, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
        self.relu1 = nn.ReLU()
        self.bn1 = nn.BatchNorm2d(8)
        init.kaiming_normal_(self.conv1.weight, a=0.1)
        self.conv1.bias.data.zero_()
        conv_layers += [self.conv1, self.relu1, self.bn1]

        # Second Convolution Block
        self.conv2 = nn.Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu2 = nn.ReLU()
        self.bn2 = nn.BatchNorm2d(16)
        init.kaiming_normal_(self.conv2.weight, a=0.1)
        self.conv2.bias.data.zero_()
        conv_layers += [self.conv2, self.relu2, self.bn2]

        # Second Convolution Block
        self.conv3 = nn.Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu3 = nn.ReLU()
        self.bn3 = nn.BatchNorm2d(32)
        init.kaiming_normal_(self.conv3.weight, a=0.1)
        self.conv3.bias.data.zero_()
        conv_layers += [self.conv3, self.relu3, self.bn3]

        # Second Convolution Block
        self.conv4 = nn.Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu4 = nn.ReLU()
        self.bn4 = nn.BatchNorm2d(64)
        init.kaiming_normal_(self.conv4.weight, a=0.1)
        self.conv4.bias.data.zero_()
        conv_layers += [self.conv4, self.relu4, self.bn4]

        # Linear Classifier
        self.ap = nn.AdaptiveAvgPool2d(output_size=1)
        self.lin = nn.Linear(in_features=64, out_features=10)

        # Wrap the Convolutional Blocks
        self.conv = nn.Sequential(*conv_layers)
 
    # ----------------------------
    # Forward pass computations
    # ----------------------------
    def forward(self, x):
        # Run the convolutional blocks
        x = self.conv(x)

        # Adaptive pool and flatten for input to linear layer
        x = self.ap(x)
        x = x.view(x.shape[0], -1)

        # Linear layer
        x = self.lin(x)

        # Final output
        return x

# Create the model and put it on the GPU if available
myModel = AudioClassifier()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
myModel = myModel.to(device)
# Check that it is on Cuda
next(myModel.parameters()).device
# Out:
# device(type='cuda', index=0)

# %%
num_epochs=200

neptune_activation = True

if neptune_activation:
  import neptune.new as neptune
  run = neptune.init(
      project="crshbng/Crash",
      api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI5YTdjYjc1OC0wMzliLTQwYzMtODRhZS05NDMzYTJjN2M0MmEifQ==",
  )  # your credentials
  params = {
      "Num. Readings": num_items,
      "Num. Types": 5,
      "Type of ML": 'CNN Classification',
      "n_epochs": num_epochs,
      "Optimizer": "Adam",
      "Batch Size": 16,
      "Kernal Size": (5,3,3,3),
      "Var":"Mel_non-aug_noise"
  }

  run["parameters"] = params

import datetime

# ----------------------------
# Training Loop
# ----------------------------
def training(model, train_dl, num_epochs):
  # Loss Function, Optimizer and Scheduler
  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
  scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.001,
                                                steps_per_epoch=int(len(train_dl)),
                                                epochs=num_epochs,
                                                anneal_strategy='linear')

  # Repeat for each epoch
  for epoch in range(num_epochs):
    running_loss = 0.0
    correct_prediction = 0
    total_prediction = 0

    # Repeat for each batch in the training set
    for i, data in enumerate(train_dl):
        # Get the input features and target labels, and put them on the GPU
        inputs, labels = data[0].to(device), data[1].to(device)

        # Normalize the inputs
        inputs_m, inputs_s = inputs.mean(), inputs.std()
        inputs = (inputs - inputs_m) / inputs_s

        # Zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        scheduler.step()

        # Keep stats for Loss and Accuracy
        running_loss += loss.item()

        # Get the predicted class with the highest score
        _, prediction = torch.max(outputs,1)
        # Count of predictions that matched the target label
        correct_prediction += (prediction == labels).sum().item()
        total_prediction += prediction.shape[0]
    
    # Print stats at the end of the epoch
    num_batches = len(train_dl)
    avg_loss = running_loss / num_batches
    acc = correct_prediction/total_prediction
    inf = inference(myModel, val_dl)
    print(f'Epoch: {epoch}, Loss: {avg_loss:.2f}, Accuracy: {acc:.2f}, Validation Accuracy: {inf[0]:.2f}')

    if neptune_activation:
      run["train/epoch/loss"].log(avg_loss)
      run["train/epoch/accuracy"].log(acc)
      run["train/epoch/inference"].log(inf[0])

  print('Finished Training')
  
  if neptune_activation:
    run.stop()
  
training(myModel, train_dl, num_epochs)
date = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
torch.save(myModel.state_dict(), f'{date}_model.pt')
# Out:
# https://app.neptune.ai/crshbng/Crash/e/CRAS-103
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# Accuracy: 0.24, Total items: 917
# Epoch: 0, Loss: 2.26, Accuracy: 0.23, Validation Accuracy: 0.24
# Accuracy: 0.25, Total items: 917
# Epoch: 1, Loss: 2.21, Accuracy: 0.25, Validation Accuracy: 0.25
# Accuracy: 0.30, Total items: 917
# Epoch: 2, Loss: 2.12, Accuracy: 0.27, Validation Accuracy: 0.30
# Accuracy: 0.35, Total items: 917
# Epoch: 3, Loss: 1.97, Accuracy: 0.33, Validation Accuracy: 0.35
# Accuracy: 0.38, Total items: 917
# Epoch: 4, Loss: 1.76, Accuracy: 0.38, Validation Accuracy: 0.38
# Accuracy: 0.40, Total items: 917
# Epoch: 5, Loss: 1.57, Accuracy: 0.40, Validation Accuracy: 0.40
# Accuracy: 0.40, Total items: 917
# Epoch: 6, Loss: 1.44, Accuracy: 0.41, Validation Accuracy: 0.40
# Accuracy: 0.45, Total items: 917
# Epoch: 7, Loss: 1.36, Accuracy: 0.43, Validation Accuracy: 0.45
# Accuracy: 0.47, Total items: 917
# Epoch: 8, Loss: 1.30, Accuracy: 0.46, Validation Accuracy: 0.47
# Accuracy: 0.49, Total items: 917
# Epoch: 9, Loss: 1.25, Accuracy: 0.48, Validation Accuracy: 0.49
# Accuracy: 0.54, Total items: 917
# Epoch: 10, Loss: 1.20, Accuracy: 0.50, Validation Accuracy: 0.54
# Accuracy: 0.57, Total items: 917
# Epoch: 11, Loss: 1.15, Accuracy: 0.54, Validation Accuracy: 0.57
# Accuracy: 0.60, Total items: 917
# Epoch: 12, Loss: 1.09, Accuracy: 0.56, Validation Accuracy: 0.60
# Accuracy: 0.60, Total items: 917
# Epoch: 13, Loss: 1.03, Accuracy: 0.60, Validation Accuracy: 0.60
Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 124, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.98, Total items: 917
# Epoch: 125, Loss: 0.02, Accuracy: 0.99, Validation Accuracy: 0.98
# Accuracy: 0.99, Total items: 917
# Epoch: 126, Loss: 0.02, Accuracy: 0.99, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 127, Loss: 0.02, Accuracy: 0.99, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 128, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.98, Total items: 917
# Epoch: 129, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.98
# Accuracy: 0.98, Total items: 917
# Epoch: 130, Loss: 0.02, Accuracy: 0.99, Validation Accuracy: 0.98
# Accuracy: 0.98, Total items: 917
# Epoch: 131, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.98
# Accuracy: 0.98, Total items: 917
# Epoch: 132, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.98
# Accuracy: 0.98, Total items: 917
# Epoch: 133, Loss: 0.02, Accuracy: 0.99, Validation Accuracy: 0.98
# Accuracy: 0.99, Total items: 917
# Epoch: 134, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 135, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 136, Loss: 0.03, Accuracy: 0.99, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 137, Loss: 0.02, Accuracy: 0.99, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 138, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 139, Loss: 0.02, Accuracy: 0.99, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 140, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 141, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 142, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 143, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 144, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.98, Total items: 917
# Epoch: 145, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.98
# Accuracy: 0.99, Total items: 917
# Epoch: 146, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 147, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 148, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.98, Total items: 917
# Epoch: 149, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.98
# Accuracy: 0.99, Total items: 917
# Epoch: 150, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 151, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 152, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 153, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 154, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 155, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 156, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 157, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 158, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 159, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 160, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 161, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 162, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 163, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 164, Loss: 0.04, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 165, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 166, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 167, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 168, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 169, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 170, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 171, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 172, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 173, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 174, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 175, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 176, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 177, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 178, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 179, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 180, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 181, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 182, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 183, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 184, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 185, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 186, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 187, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 188, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 189, Loss: 0.02, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 190, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 191, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 192, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 1.00, Total items: 917
# Epoch: 193, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 1.00
# Accuracy: 0.99, Total items: 917
# Epoch: 194, Loss: 0.00, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 195, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 196, Loss: 0.00, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 197, Loss: 0.01, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 198, Loss: 0.00, Accuracy: 1.00, Validation Accuracy: 0.99
# Accuracy: 0.99, Total items: 917
# Epoch: 199, Loss: 0.00, Accuracy: 1.00, Validation Accuracy: 0.99
# Finished Training
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 10 operations to synchronize with Neptune. Do not kill this process.
# All 10 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/crshbng/Crash/e/CRAS-103

# %%
def inference (model, val_dl):
    correct_prediction = 0
    total_prediction = 0
    wrong=[]

  # Disable gradient updates
    with torch.no_grad():
        for data in val_dl:
      # Get the input features and target labels, and put them on the GPU
            inputs, labels = data[0].to(device), data[1].to(device)

      # Normalize the inputs
            inputs_m, inputs_s = inputs.mean(), inputs.std()
            inputs = (inputs - inputs_m) / inputs_s

      # Get predictions
            outputs = model(inputs)

      # Get the predicted class with the highest score
            _, prediction = torch.max(outputs,1)
            cpu_prediction = prediction.cpu().numpy()
            cpu_labels = labels.cpu().numpy()
            for i in range(len(cpu_prediction)):
                if cpu_prediction[i]!=cpu_labels[i]:
                    wrong.append([cpu_prediction[i],cpu_labels[i]])
                    
      # Count of predictions that matched the target label
            correct_prediction += (prediction == labels).sum().item()
            total_prediction += prediction.shape[0]
    #print(wrong)
    acc = correct_prediction/total_prediction
    print(f'Accuracy: {acc:.2f}, Total items: {total_prediction}')
    return acc,wrong

# %%
total = []
inc=[]
for i in range(10):
    val,wrong=inference(myModel, val_dl)
    total.append(val)
    inc.append(wrong)
# Out:
# Accuracy: 0.99, Total items: 917
# Accuracy: 0.99, Total items: 917
# Accuracy: 0.99, Total items: 917
# Accuracy: 0.99, Total items: 917
# Accuracy: 0.99, Total items: 917
# Accuracy: 0.99, Total items: 917
# Accuracy: 0.99, Total items: 917
# Accuracy: 0.99, Total items: 917
# Accuracy: 0.99, Total items: 917
# Accuracy: 0.99, Total items: 917

# %%
print(f"{100*np.mean(total)} +/- {100*(np.std(total)/len(total))} %")
# Out:
# 99.14940021810251 +/- 0.019385374955977305 %
